# %%
import pandas as pd
reviews = pd.read_csv("C:/Users/Rob/Downloads/ign.csv")

# %%
reviews.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
reviews.iloc[9,:]
# Out:
# Unnamed: 0                                                9
# score_phrase                                           Good
# title                             Total War Battles: Shogun
# url               /games/total-war-battles-shogun/pc-142564
# platform                                                 PC
# score                                                     7
# genre                                              Strategy
# editors_choice                                            N
# release_year                                           2012
# release_month                                             9
# release_day                                              11
# Name: 9, dtype: object

# %%
some_reviews = reviews.loc[10:20,["title","score"]]
some_reviews.head()
# Out:
#                       title  score
# 10  Tekken Tag Tournament 2    7.5
# 11  Tekken Tag Tournament 2    7.5
# 12               Wild Blood    7.0
# 13        Mark of the Ninja    9.0
# 14        Mark of the Ninja    9.0

# %%
reviews[["score", "release_year"]]
# Out:
#        score  release_year
# 0        9.0          2012
# 1        9.0          2012
# 2        8.5          2012
# 3        8.5          2012
# 4        8.5          2012
# 5        7.0          2012
# 6        3.0          2012
# 7        9.0          2012
# 8        3.0          2012
# 9        7.0          2012
# 10       7.5          2012
# 11       7.5          2012
# 12       7.0          2012
# 13       9.0          2012
# 14       9.0          2012
# 15       6.5          2012
# 16       6.5          2012
# 17       8.0          2012
# 18       5.5          2012
# 19       7.0          2012
# 20       7.0          2012
# 21       7.5          2012
# 22       7.5          2012
# 23       7.5          2012
# 24       9.0          2012
# 25       7.0          2012
# 26       9.0          2012
# 27       7.5          2012
# 28       8.0          2012
# 29       6.5          2012
# ...      ...           ...
# 18595    4.4          2016
# 18596    6.5          2016
# ...

# %%
type(reviews["score"])
# Out:
# pandas.core.series.Series

# %%
s1 = pd.Series([1,2])
s1
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
s2 = pd.Series(["Ranger", "Magus"])
s2
# Out:
# 0    Ranger
# 1     Magus
# dtype: object

# %%
pd.DataFrame([s1,s2])
# Out:
#         0      1
# 0       1      2
# 1  Ranger  Magus

# %%
frame = pd.DataFrame(
    [
    [1,2],
    ["Boris Yeltsin", "Mikhail Gorbachev"]
    ],
    index=["row1", "row2"],
    columns=["column1", "column2"]
)
frame
# Out:
#             column1            column2
# row1              1                  2
# row2  Boris Yeltsin  Mikhail Gorbachev

# %%
frame.loc["row1":"row2", "column1"]
# Out:
# row1                1
# row2    Boris Yeltsin
# Name: column1, dtype: object

# %%
myframe = pd.DataFrame({"Name":["Bob","Ted","John"], "Age":[35,56,67]})
myframe
# Out:
#    Name  Age
# 0   Bob   35
# 1   Ted   56
# 2  John   67

# %%
myframe.Name
# Out:
# 0     Bob
# 1     Ted
# 2    John
# Name: Name, dtype: object

# %%
reviews.score.mean()
# Out:
# 6.950459060402666
